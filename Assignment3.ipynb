# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# C:\Users\Mudassir\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
plt.scatter(iris['sepal_width'],iris['sepal_length'])
plt.title('Iris Data of Sepal')
plt.xlabel('Width')
plt.ylabel('Length')
plt.show()

# %%
sns.scatterplot(x="sepal_width",y="sepal_length",data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
plt.scatter(iris['petal_width'],iris['petal_length'],color='green')
plt.title('Iris Data of Petal')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')
plt.show()

# %%
plt.bar(iris['sepal_width'],iris['petal_length'], color = "purple")
plt.xlabel("Sepal Width")
plt.ylabel("Petal Length")
plt.title("Sepal Width vs Petal Length")
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(iris['sepal_width'],iris['sepal_length'] , color = "orange")
plt.subplot(2,2,2)
plt.bar(iris['sepal_width'],iris['sepal_length'] , color = "red")
plt.subplot(2,2,3)
plt.scatter(iris['sepal_width'],iris['sepal_length'] , color = "magenta")
plt.show()

# %%
plt.scatter(iris['sepal_width'],iris['sepal_length'],label = "Sepal width vs length")
plt.scatter(iris['sepal_length'],iris['sepal_width'],label = "Sepal length vs width")
plt.legend()
plt.show()

# %%
sns.lineplot(x = iris['sepal_width'],y=iris['sepal_length'],data = iris,ci=None)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
sns.distplot(iris["sepal_width"])
# Out:
# C:\Users\Mudassir\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %%
sns.distplot(iris["petal_width"])
# Out:
# C:\Users\Mudassir\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %%
sns.barplot(x='species', y = 'sepal_length', data= iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x='species', y = 'sepal_width', data= iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.barplot(x='species', y = 'petal_length', data= iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.barplot(x='species', y = 'petal_width', data= iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.countplot(x="species", data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.boxplot(x = "species",y = "sepal_width",data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(x = "species",y = "sepal_length",data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.catplot(x = "species",y = "petal_width",hue = "petal_length",data = iris)

# %%
sns.catplot(x = "species",y = "sepal_length",hue = "sepal_width",data = iris)

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), annot = True)
